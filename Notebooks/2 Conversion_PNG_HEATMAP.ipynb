# %%
import numpy as np
import pandas as pd
import os
import cv2
import tensorflow as tf
# Modelo preentrenado
from tensorflow.keras.applications import VGG16
from tensorflow.keras.models import Model

# %%
train_df = pd.read_csv('train.csv')

test_df = pd.read_csv('test.csv')


base_path='train_images'

# saving image path into train dataframe
train_df['img_path']= f'{base_path}'\
                    + '/' + train_df.patient_id.astype(str)\
                    + '/' + train_df.image_id.astype(str)\
                    + '.png'



display(train_df.head(3))
# Out:
#    site_id  patient_id    image_id laterality view   age  cancer  biopsy  \
# 0        2       10006   462822612          L   CC  61.0       0       0
# 1        2       10006  1459541791          L  MLO  61.0       0       0
# 2        2       10006  1864590858          R  MLO  61.0       0       0
#
#    invasive  BIRADS  implant density  machine_id  difficult_negative_case  \
# 0         0     NaN        0     NaN          29                    False
# 1         0     NaN        0     NaN          29                    False
# 2         0     NaN        0     NaN          29                    False
#
#                             img_path
# 0   train_images/10006/462822612.png
# 1  train_images/10006/1459541791.png
# 2  train_images/10006/1864590858.png

# %%
patients_with_nan_BIRADS = train_df[train_df['BIRADS'].isna()]
patients_with_cancer_nan_BIRADS = patients_with_nan_BIRADS[patients_with_nan_BIRADS['cancer'] == 1]

# Cantidad de pancientes con cancer y clasificación BIRADS nan
print(len(patients_with_cancer_nan_BIRADS))
# Out:
# 494

# %%
# Analizar la distribución de BI-RADS (asume que es una columna llamada 'BIRADS')
birads = train_df['BIRADS'].dropna()

# %%
# Calcular las probabilidades dinámicamente
available_birads = train_df['BIRADS'].dropna()  # Valores disponibles
birads_probs = available_birads.value_counts(normalize=True).sort_index().to_list()

# Función para simular valores faltantes
def simulate_categorical_birads(size, probs):
    categories = [0, 1, 2]  # Los valores posibles de BI-RADS
    simulated_values = np.random.choice(categories, size=size, p=probs)
    return simulated_values

np.random.seed(42)  # Para reproducibilidad

# Identificar los índices con valores faltantes
missing_indices = train_df[train_df['BIRADS'].isnull()].index
num_missing = len(missing_indices)

# Simular los valores faltantes usando las probabilidades dinámicas
simulated_birads = simulate_categorical_birads(num_missing, birads_probs)

# Imputar los valores simulados
train_df.loc[missing_indices, 'BIRADS'] = simulated_birads

# %%
#Cálculo de las probabilidades dinamicamente
# Filtrar los datos disponibles
available_density = train_df['density'].dropna()

# Calcular las frecuencias relativas
density_probs = available_density.value_counts(normalize=True).sort_index().to_list()
print(f"Probabilidades calculadas dinámicamente: {density_probs}")
# Out:
# Probabilidades calculadas dinámicamente: [0.10536138445877163, 0.4292840176450628, 0.41313199864268746, 0.052222599253478115]

# %%
minority_class_size = train_df['cancer'].value_counts().min()

# Definir la proporción de muestras de la clase mayoritaria (ejemplo: 2 veces la clase minoritaria)
majority_class_multiplier = 10
majority_class_size = minority_class_size * majority_class_multiplier

# Obtener todas las muestras de la clase minoritaria
minority_samples = train_df[train_df['cancer'] == 1]

# Obtener una muestra aleatoria de la clase mayoritaria
majority_samples = train_df[train_df['cancer'] == 0].sample(majority_class_size, random_state=42)

# Combinar las muestras de ambas clases
balanced_df = pd.concat([minority_samples, majority_samples]).sample(frac=1, random_state=42).reset_index(drop=True)

# Verificar el balance de clases
print(balanced_df['cancer'].value_counts())
# Out:
# cancer
# 0    11580
# 1     1158
# Name: count, dtype: int64

# %%
# Cargar modelo una vez al inicio
model = VGG16(weights="imagenet")
grad_model = Model(inputs=model.inputs, outputs=[model.get_layer("block5_conv3").output, model.output])

# %%
# Función para generar heatmap
def generate_heatmap(image_path):
    print("Generating heatmap")
    img = cv2.imread(image_path)
    img = cv2.resize(img, (224, 224))  # Ajustar tamaño para el modelo
    img_array = np.expand_dims(img, axis=0)
    img_array = tf.keras.applications.vgg16.preprocess_input(img_array)

    with tf.GradientTape() as tape:
        conv_outputs, predictions = grad_model(img_array)
        class_idx = tf.argmax(predictions[0])
        loss = predictions[:, class_idx]

    grads = tape.gradient(loss, conv_outputs)[0]
    weights = tf.reduce_mean(grads, axis=(0, 1))
    heatmap = tf.reduce_sum(weights * conv_outputs[0], axis=-1)

        # Normalizar heatmap
    heatmap = np.maximum(heatmap, 0) / np.max(heatmap)
    if not isinstance(heatmap, np.ndarray):  # Si no es un array de NumPy, conviértelo
        heatmap = heatmap.numpy()
    heatmap = cv2.resize(heatmap, (512, 512))  # Redimensionar al tamaño original
    heatmap = (heatmap * 255).astype("uint8")
    return heatmap

# Superponer heatmap
def apply_heatmap(image_path, heatmap, alpha=0.6):
    print("Superponiendo heatmap")
    original_image = cv2.imread(image_path)
    heatmap_color = cv2.applyColorMap(heatmap, cv2.COLORMAP_JET)
    overlay = cv2.addWeighted(heatmap_color, alpha, original_image, 1 - alpha, 0)
    return overlay

# Función para procesar una imagen
def process_image(row):
    print("Guardando heatmap")
    input_path = row['img_path']
    output_dir = "images_processed_heatmap"  # Cambiar por tu ruta de salida
    os.makedirs(output_dir, exist_ok=True)
    
    try:
        heatmap = generate_heatmap(input_path)
        transformed_image = apply_heatmap(input_path, heatmap)

        # Generar salida en la misma estructura
        relative_path = os.path.relpath(input_path, start="train_images")
        output_path = os.path.join(output_dir, relative_path)
        os.makedirs(os.path.dirname(output_path), exist_ok=True)
        
        cv2.imwrite(output_path, transformed_image)
        return f"Procesada: {output_path}"
    except Exception as e:
        return f"Error en {input_path}: {str(e)}"

# %%
for _, row in balanced_df.iterrows():
    print(process_image(row))
# Out:
# Guardando heatmap
# Generating heatmap
# c:\Users\Melissa\Ambientes\venv_integrador_2\Lib\site-packages\keras\src\models\functional.py:225: UserWarning: The structure of `inputs` doesn't match the expected structure: ['keras_tensor']. Received: the structure of inputs=*
#   warnings.warn(
# Superponiendo heatmap
# Procesada: images_processed_heatmap\65030\1344606626.png
# Guardando heatmap
# Generating heatmap
# Superponiendo heatmap
# Procesada: images_processed_heatmap\31859\78460969.png
# Guardando heatmap
# Generating heatmap
# Superponiendo heatmap
# Procesada: images_processed_heatmap\7098\786606520.png
# Guardando heatmap
# Generating heatmap
# Superponiendo heatmap
# Procesada: images_processed_heatmap\31277\401242910.png
# Guardando heatmap
# Generating heatmap
# Superponiendo heatmap
# Procesada: images_processed_heatmap\22562\1491977729.png
# Guardando heatmap
# Generating heatmap
# Superponiendo heatmap
# Procesada: images_processed_heatmap\8570\2139613775.png
# Guardando heatmap
# Generating heatmap
# Superponiendo heatmap
# Procesada: images_processed_heatmap\18421\179426017.png
# Guardando heatmap
# Generating heatmap
# Superponiendo heatmap
# Procesada: images_processed_heatmap\17570\130190871.png
# Guardando heatmap
# Generating heatmap
# Superponiendo heatmap
# Procesada: images_processed_heatmap\9750\1208494128.png
# Guardando heatmap
# Generating heatmap
# Superponiendo heatmap
# Procesada: images_processed_heatmap\9851\1434430689.png
# Guardando heatmap
# Generating heatmap
# Superponiendo heatmap
# Procesada: images_processed_heatmap\4930\1762124568.png
# Guardando heatmap
# Generating heatmap
# Superponiendo heatmap
# Procesada: images_processed_heatmap\1826\678445924.png
# Guardando heatmap
# Generating heatmap
# Superponiendo heatmap
# Procesada: images_processed_heatmap\26351\746567210.png
# Guardando heatmap
# Generating heatmap
# Superponiendo heatmap
# Procesada: images_processed_heatmap\39968\1783290342.png
# Guardando heatmap
# Generating heatmap
# Superponiendo heatmap
# Procesada: images_processed_heatmap\48879\1874600209.png
# Guardando heatmap
# Generating heatmap
# Superponiendo heatmap
# Procesada: images_processed_heatmap\58336\44253243.png
# Guardando heatmap
# Generating heatmap
# Superponiendo heatmap
# Procesada: images_processed_heatmap\13158\1763611111.png
# Guardando heatmap
# Generating heatmap
# Superponiendo heatmap
# Procesada: images_processed_heatmap\44055\556338734.png
# Guardando heatmap
# Generating heatmap
# Superponiendo heatmap
# Procesada: images_processed_heatmap\32011\1819205027.png
# Guardando heatmap
# Generating heatmap
# Superponiendo heatmap
# Procesada: images_processed_heatmap\53628\112252638.png
# Guardando heatmap
# Generating heatmap
# Superponiendo heatmap
# Procesada: images_processed_heatmap\55166\1173456914.png
# Guardando heatmap
# Generating heatmap
# Superponiendo heatmap
# Procesada: images_processed_heatmap\48099\29822556.png
# Guardando heatmap
# Generating heatmap
# Superponiendo heatmap
# Procesada: images_processed_heatmap\56118\509015173.png
# Guardando heatmap
# Generating heatmap
# Superponiendo heatmap
# Procesada: images_processed_heatmap\16955\148322351.png
# Guardando heatmap
# Generating heatmap
# Superponiendo heatmap
# Procesada: images_processed_heatmap\36979\464225360.png
# Guardando heatmap
# Generating heatmap
# Superponiendo heatmap
# Procesada: images_processed_heatmap\13695\507698655.png
# Guardando heatmap
# Generating heatmap
# Superponiendo heatmap
# Procesada: images_processed_heatmap\1724\1305183381.png
# Guardando heatmap
# Generating heatmap
# Superponiendo heatmap
# Procesada: images_processed_heatmap\10217\1564477624.png
# Guardando heatmap
# Generating heatmap
# Superponiendo heatmap
# Procesada: images_processed_heatmap\27857\124777991.png
# Guardando heatmap
# Generating heatmap
# Superponiendo heatmap
# Procesada: images_processed_heatmap\25356\1956625879.png
# Guardando heatmap
# Generating heatmap
# Superponiendo heatmap
# Procesada: images_processed_heatmap\27514\2027953447.png
# Guardando heatmap
# Generating heatmap
# Superponiendo heatmap
# Procesada: images_processed_heatmap\17491\1025754895.png
# Guardando heatmap
# Generating heatmap
# Superponiendo heatmap
# Procesada: images_processed_heatmap\45229\1247287220.png
# Guardando heatmap
# Generating heatmap
# Superponiendo heatmap
# Procesada: images_processed_heatmap\18797\849365885.png
# Guardando heatmap
# Generating heatmap
# Superponiendo heatmap
# Procesada: images_processed_heatmap\1983\54882879.png
# Guardando heatmap
# Generating heatmap
# Superponiendo heatmap
# Procesada: images_processed_heatmap\9340\43376513.png
# Guardando heatmap
# Generating heatmap
# Superponiendo heatmap
# Procesada: images_processed_heatmap\65053\1847979431.png
# Guardando heatmap
# Generating heatmap
# Superponiendo heatmap
# Procesada: images_processed_heatmap\41647\1821746684.png
# Guardando heatmap
# Generating heatmap
# Superponiendo heatmap
# Procesada: images_processed_heatmap\27563\17798938.png
# Guardando heatmap
# Generating heatmap
# Superponiendo heatmap
# Procesada: images_processed_heatmap\27089\979234200.png
# Guardando heatmap
# Generating heatmap
# Superponiendo heatmap
# Procesada: images_processed_heatmap\46176\532327601.png
# Guardando heatmap
# Generating heatmap
# Superponiendo heatmap
# Procesada: images_processed_heatmap\45209\1520621038.png
# Guardando heatmap
# Generating heatmap
# Superponiendo heatmap
# Procesada: images_processed_heatmap\60739\841165053.png
# Guardando heatmap
# Generating heatmap
# Superponiendo heatmap
# Procesada: images_processed_heatmap\39525\751000807.png
# Guardando heatmap
# Generating heatmap
# Superponiendo heatmap
# Procesada: images_processed_heatmap\22700\1984562699.png
# Guardando heatmap
# Generating heatmap
# Superponiendo heatmap
# Procesada: images_processed_heatmap\43555\408173238.png
# Guardando heatmap
# Generating heatmap
# Superponiendo heatmap
# Procesada: images_processed_heatmap\12149\1006821991.png
# Guardando heatmap
# Generating heatmap
# Superponiendo heatmap
# Procesada: images_processed_heatmap\14181\788855744.png
# Guardando heatmap
# Generating heatmap
# Superponiendo heatmap
# Procesada: images_processed_heatmap\45624\474157844.png
# Guardando heatmap
# Generating heatmap
# Superponiendo heatmap
# Procesada: images_processed_heatmap\47056\1648933707.png
# Guardando heatmap
# Generating heatmap
# Superponiendo heatmap
# Procesada: images_processed_heatmap\4817\1476666475.png
# Guardando heatmap
# Generating heatmap
# Superponiendo heatmap
# Procesada: images_processed_heatmap\8992\1080798770.png
# Guardando heatmap
# Generating heatmap
# Superponiendo heatmap
# Procesada: images_processed_heatmap\2004\643865876.png
# Guardando heatmap
# Generating heatmap
# Superponiendo heatmap
# Procesada: images_processed_heatmap\20954\1502690495.png
# Guardando heatmap
# Generating heatmap
# Superponiendo heatmap
# Procesada: images_processed_heatmap\59978\165361033.png
# Guardando heatmap
# Generating heatmap
# Superponiendo heatmap
# Procesada: images_processed_heatmap\7220\1341902373.png
# Guardando heatmap
# Generating heatmap
# Superponiendo heatmap
# Procesada: images_processed_heatmap\7545\1675539843.png
# Guardando heatmap
# Generating heatmap
# Superponiendo heatmap
# Procesada: images_processed_heatmap\40822\1073304093.png
# Guardando heatmap
# Generating heatmap
# Superponiendo heatmap
# Procesada: images_processed_heatmap\79\324319833.png
# Guardando heatmap
# Generating heatmap
# Superponiendo heatmap
# Procesada: images_processed_heatmap\31107\561482287.png
# Guardando heatmap
# Generating heatmap
# Superponiendo heatmap
# Procesada: images_processed_heatmap\9113\2040407406.png
# Guardando heatmap
# Generating heatmap
# Superponiendo heatmap
# Procesada: images_processed_heatmap\9029\2042108582.png
# Guardando heatmap
# Generating heatmap
# Superponiendo heatmap
# Procesada: images_processed_heatmap\39611\122457445.png
# Guardando heatmap
# Generating heatmap
# Superponiendo heatmap
# Procesada: images_processed_heatmap\56107\1535406528.png
# Guardando heatmap
# Generating heatmap
# Superponiendo heatmap
# Procesada: images_processed_heatmap\61825\1951468322.png
# Guardando heatmap
# Generating heatmap
# Superponiendo heatmap
# Procesada: images_processed_heatmap\62752\1340474502.png
# Guardando heatmap
# Generating heatmap
# Superponiendo heatmap
# Procesada: images_processed_heatmap\56608\1783887597.png
# Guardando heatmap
# Generating heatmap
# Superponiendo heatmap
# Procesada: images_processed_heatmap\58953\1421128330.png
# Guardando heatmap
# Generating heatmap
# Superponiendo heatmap
# Procesada: images_processed_heatmap\61480\741532552.png
# Guardando heatmap
# Generating heatmap
# Superponiendo heatmap
# Procesada: images_processed_heatmap\4610\1617434807.png
# Guardando heatmap
# Generating heatmap
# Superponiendo heatmap
# Procesada: images_processed_heatmap\29606\670897763.png
# Guardando heatmap
# Generating heatmap
# Superponiendo heatmap
# Procesada: images_processed_heatmap\60511\1236758953.png
# Guardando heatmap
# Generating heatmap
# Superponiendo heatmap
# Procesada: images_processed_heatmap\14687\548847251.png
# Guardando heatmap
# Generating heatmap
# Superponiendo heatmap
# Procesada: images_processed_heatmap\64554\2030467391.png
# Guardando heatmap
# Generating heatmap
# Superponiendo heatmap
# Procesada: images_processed_heatmap\22887\806011842.png
# Guardando heatmap
# Generating heatmap
# Superponiendo heatmap
# Procesada: images_processed_heatmap\63675\507452850.png
# Guardando heatmap
# Generating heatmap
# Superponiendo heatmap
# Procesada: images_processed_heatmap\46707\921695598.png
# Guardando heatmap
# Generating heatmap
# Superponiendo heatmap
# Procesada: images_processed_heatmap\22985\1833980871.png
# Guardando heatmap
# Generating heatmap
# Superponiendo heatmap
# Procesada: images_processed_heatmap\28221\312864851.png
# Guardando heatmap
# Generating heatmap
# Superponiendo heatmap
# Procesada: images_processed_heatmap\20500\1954126482.png
# Guardando heatmap
# Generating heatmap
# Superponiendo heatmap
# Procesada: images_processed_heatmap\27496\918956669.png
# Guardando heatmap
# Generating heatmap
# Superponiendo heatmap
# Procesada: images_processed_heatmap\53098\1378859942.png
# Guardando heatmap
# Generating heatmap
# Superponiendo heatmap
# Procesada: images_processed_heatmap\60251\366272256.png
# Guardando heatmap
# Generating heatmap
# Superponiendo heatmap
# Procesada: images_processed_heatmap\44906\1995683150.png
# Guardando heatmap
# Generating heatmap
# Superponiendo heatmap
# Procesada: images_processed_heatmap\52334\1438120661.png
# Guardando heatmap
# Generating heatmap
# Superponiendo heatmap
# Procesada: images_processed_heatmap\12563\598311773.png
# Guardando heatmap
# Generating heatmap
# Superponiendo heatmap
# Procesada: images_processed_heatmap\32272\125747255.png
# Guardando heatmap
# Generating heatmap
# Superponiendo heatmap
# Procesada: images_processed_heatmap\41369\1721828196.png
# Guardando heatmap
# Generating heatmap
# Superponiendo heatmap
# Procesada: images_processed_heatmap\40908\135426241.png
# Guardando heatmap
# Generating heatmap
# Superponiendo heatmap
# Procesada: images_processed_heatmap\8793\1719769979.png
# Guardando heatmap
# Generating heatmap
# Superponiendo heatmap
# Procesada: images_processed_heatmap\19971\45160772.png
# Guardando heatmap
# Generating heatmap
# Superponiendo heatmap
# Procesada: images_processed_heatmap\45810\1648038129.png
# Guardando heatmap
# Generating heatmap
# Superponiendo heatmap
# Procesada: images_processed_heatmap\22646\1411702523.png
# Guardando heatmap
# Generating heatmap
# Superponiendo heatmap
# Procesada: images_processed_heatmap\20508\1718189157.png
# Guardando heatmap
# Generating heatmap
# Superponiendo heatmap
# Procesada: images_processed_heatmap\8785\1906919388.png
# Guardando heatmap
# Generating heatmap
# Superponiendo heatmap
# Procesada: images_processed_heatmap\63836\412431035.png
# Guardando heatmap
# Generating heatmap
# Superponiendo heatmap
# Procesada: images_processed_heatmap\26368\1075818994.png
# Guardando heatmap
# Generating heatmap
# Superponiendo heatmap
# Procesada: images_processed_heatmap\44443\1194403996.png
# Guardando heatmap
# Generating heatmap
# Superponiendo heatmap
# Procesada: images_processed_heatmap\22397\738319186.png
# Guardando heatmap
# Generating heatmap
# Superponiendo heatmap
# Procesada: images_processed_heatmap\24016\638244501.png
# Guardando heatmap
# Generating heatmap
# Superponiendo heatmap
# Procesada: images_processed_heatmap\15066\1708980845.png
# Guardando heatmap
# Generating heatmap
# Superponiendo heatmap
# Procesada: images_processed_heatmap\40317\877739785.png
# Guardando heatmap
# Generating heatmap
# Superponiendo heatmap
# Procesada: images_processed_heatmap\55611\675478055.png
# Guardando heatmap
# Generating heatmap
# Superponiendo heatmap
# Procesada: images_processed_heatmap\37100\206462506.png
# Guardando heatmap
# Generating heatmap
# Superponiendo heatmap
# Procesada: images_processed_heatmap\15951\390162528.png
# Guardando heatmap
# Generating heatmap
# Superponiendo heatmap
# Procesada: images_processed_heatmap\56308\224574481.png
# Guardando heatmap
# Generating heatmap
# Superponiendo heatmap
# Procesada: images_processed_heatmap\2482\424945901.png
# Guardando heatmap
# Generating heatmap
# Superponiendo heatmap
# Procesada: images_processed_heatmap\17704\1597800568.png
# Guardando heatmap
# Generating heatmap
# Superponiendo heatmap
# Procesada: images_processed_heatmap\17416\2128733531.png
# Guardando heatmap
# Generating heatmap
# Superponiendo heatmap
# Procesada: images_processed_heatmap\28702\992732659.png
# Guardando heatmap
# Generating heatmap
# Superponiendo heatmap
# Procesada: images_processed_heatmap\50328\788501336.png
# Guardando heatmap
# Generating heatmap
# Superponiendo heatmap
# Procesada: images_processed_heatmap\5199\1908030778.png
# Guardando heatmap
# Generating heatmap
# Superponiendo heatmap
# Procesada: images_processed_heatmap\36469\543745274.png
# Guardando heatmap
# Generating heatmap
# Superponiendo heatmap
# Procesada: images_processed_heatmap\35864\1558139643.png
# Guardando heatmap
# Generating heatmap
# Superponiendo heatmap
# Procesada: images_processed_heatmap\22182\1601991131.png
# Guardando heatmap
# Generating heatmap
# Superponiendo heatmap
# Procesada: images_processed_heatmap\50896\549033502.png
# Guardando heatmap
# Generating heatmap
# Superponiendo heatmap
# Procesada: images_processed_heatmap\63351\1425321978.png
# Guardando heatmap
# Generating heatmap
# Superponiendo heatmap
# Procesada: images_processed_heatmap\58743\1789894234.png
# Guardando heatmap
# Generating heatmap
# Superponiendo heatmap
# Procesada: images_processed_heatmap\2756\2091139179.png
# Guardando heatmap
# Generating heatmap
# Superponiendo heatmap
# Procesada: images_processed_heatmap\4439\1634431375.png
# Guardando heatmap
# Generating heatmap
# Superponiendo heatmap
# Procesada: images_processed_heatmap\55138\292443870.png
# Guardando heatmap
# Generating heatmap
# Superponiendo heatmap
# Procesada: images_processed_heatmap\31781\1691382093.png
# Guardando heatmap
# Generating heatmap
# Superponiendo heatmap
# Procesada: images_processed_heatmap\8317\2115609612.png
# Guardando heatmap
# Generating heatmap
# Superponiendo heatmap
# Procesada: images_processed_heatmap\34933\689216645.png
# Guardando heatmap
# Generating heatmap
# Superponiendo heatmap
# Procesada: images_processed_heatmap\21640\12162702.png
# Guardando heatmap
# Generating heatmap
# Superponiendo heatmap
# Procesada: images_processed_heatmap\20500\691233033.png
# Guardando heatmap
# Generating heatmap
# Superponiendo heatmap
# Procesada: images_processed_heatmap\53572\906887214.png
# Guardando heatmap
# Generating heatmap
# Superponiendo heatmap
# Procesada: images_processed_heatmap\31055\351970658.png
# Guardando heatmap
# Generating heatmap
# Superponiendo heatmap
# Procesada: images_processed_heatmap\54715\74401871.png
# Guardando heatmap
# Generating heatmap
# Superponiendo heatmap
# Procesada: images_processed_heatmap\19257\1529246190.png
# Guardando heatmap
# Generating heatmap
# Superponiendo heatmap
# Procesada: images_processed_heatmap\32587\1750435850.png
# Guardando heatmap
# Generating heatmap
# Superponiendo heatmap
# Procesada: images_processed_heatmap\38559\725368397.png
# Guardando heatmap
# Generating heatmap
# Superponiendo heatmap
# Procesada: images_processed_heatmap\26940\229489132.png
# Guardando heatmap
# Generating heatmap
# Superponiendo heatmap
# Procesada: images_processed_heatmap\53628\180122121.png
# Guardando heatmap
# Generating heatmap
# Superponiendo heatmap
# Procesada: images_processed_heatmap\56772\1899217489.png
# Guardando heatmap
# Generating heatmap
# Superponiendo heatmap
# Procesada: images_processed_heatmap\9569\910680126.png
# Guardando heatmap
# Generating heatmap
# Superponiendo heatmap
# Procesada: images_processed_heatmap\45961\1745274991.png
# Guardando heatmap
# Generating heatmap
# Superponiendo heatmap
# Procesada: images_processed_heatmap\2896\1366830826.png
# Guardando heatmap
# Generating heatmap
# Superponiendo heatmap
# Procesada: images_processed_heatmap\49344\113472614.png
# Guardando heatmap
# Generating heatmap
# Superponiendo heatmap
# Procesada: images_processed_heatmap\30326\1480603620.png
# Guardando heatmap
# Generating heatmap
# Superponiendo heatmap
# Procesada: images_processed_heatmap\56468\1525126403.png
# Guardando heatmap
# Generating heatmap
# Superponiendo heatmap
# Procesada: images_processed_heatmap\57280\1571132579.png
# Guardando heatmap
# Generating heatmap
# Superponiendo heatmap
# Procesada: images_processed_heatmap\14664\261504736.png
# Guardando heatmap
# Generating heatmap
# Superponiendo heatmap
# Procesada: images_processed_heatmap\2408\1275824330.png
# Guardando heatmap
# Generating heatmap
# Superponiendo heatmap
# Procesada: images_processed_heatmap\12571\1582253382.png
# Guardando heatmap
# Generating heatmap
# Superponiendo heatmap
# Procesada: images_processed_heatmap\48368\1464175162.png
# Guardando heatmap
# Generating heatmap
# Superponiendo heatmap
# Procesada: images_processed_heatmap\63890\854420719.png
# Guardando heatmap
# Generating heatmap
# Superponiendo heatmap
# Procesada: images_processed_heatmap\55802\1891084069.png
# Guardando heatmap
# Generating heatmap
# Superponiendo heatmap
# Procesada: images_processed_heatmap\28522\170367972.png
# Guardando heatmap
# Generating heatmap
# Superponiendo heatmap
# Procesada: images_processed_heatmap\56888\2074846636.png
# Guardando heatmap
# Generating heatmap
# Superponiendo heatmap
# Procesada: images_processed_heatmap\37467\243709522.png
# Guardando heatmap
# Generating heatmap
# Superponiendo heatmap
# Procesada: images_processed_heatmap\58291\2146705740.png
# Guardando heatmap
# Generating heatmap
# Superponiendo heatmap
# Procesada: images_processed_heatmap\9599\772180576.png
# Guardando heatmap
# Generating heatmap
# Superponiendo heatmap
# Procesada: images_processed_heatmap\11614\1105559466.png
# Guardando heatmap
# Generating heatmap
# Superponiendo heatmap
# Procesada: images_processed_heatmap\46798\1975228555.png
# Guardando heatmap
# Generating heatmap
# Superponiendo heatmap
# Procesada: images_processed_heatmap\15867\2120961337.png
# Guardando heatmap
# Generating heatmap
# Superponiendo heatmap
# Procesada: images_processed_heatmap\39739\1500311984.png
# Guardando heatmap
# Generating heatmap
# Superponiendo heatmap
# Procesada: images_processed_heatmap\31766\4945878.png
# Guardando heatmap
# Generating heatmap
# Superponiendo heatmap
# Procesada: images_processed_heatmap\55385\1398385271.png
# Guardando heatmap
# Generating heatmap
# Superponiendo heatmap
# Procesada: images_processed_heatmap\27306\1588576165.png
# Guardando heatmap
# Generating heatmap
# Superponiendo heatmap
# Procesada: images_processed_heatmap\45763\73649834.png
# Guardando heatmap
# Generating heatmap
# Superponiendo heatmap
# Procesada: images_processed_heatmap\20400\1923046542.png
# Guardando heatmap
# Generating heatmap
# Superponiendo heatmap
# Procesada: images_processed_heatmap\64818\1669032358.png
# Guardando heatmap
# Generating heatmap
# Superponiendo heatmap
# Procesada: images_processed_heatmap\60892\143748926.png
# Guardando heatmap
# Generating heatmap
# Superponiendo heatmap
# Procesada: images_processed_heatmap\4662\1899867.png
# Guardando heatmap
# Generating heatmap
# Superponiendo heatmap
# Procesada: images_processed_heatmap\2704\166586882.png
# Guardando heatmap
# Generating heatmap
# Superponiendo heatmap
# Procesada: images_processed_heatmap\33233\623599968.png
# Guardando heatmap
# Generating heatmap
# Superponiendo heatmap
# Procesada: images_processed_heatmap\7086\1316281524.png
# Guardando heatmap
# Generating heatmap
# Superponiendo heatmap
# Procesada: images_processed_heatmap\41359\1030582639.png
# Guardando heatmap
# Generating heatmap
# Superponiendo heatmap
# Procesada: images_processed_heatmap\55224\2091085892.png
# Guardando heatmap
# Generating heatmap
# Superponiendo heatmap
# Procesada: images_processed_heatmap\6654\2126262062.png
# Guardando heatmap
# Generating heatmap
# Superponiendo heatmap
# Procesada: images_processed_heatmap\827\1245477821.png
# Guardando heatmap
# Generating heatmap
# Superponiendo heatmap
# Procesada: images_processed_heatmap\47789\1609988311.png
# Guardando heatmap
# Generating heatmap
# Superponiendo heatmap
# Procesada: images_processed_heatmap\47206\2006506592.png
# Guardando heatmap
# Generating heatmap
# Superponiendo heatmap
# Procesada: images_processed_heatmap\43880\290983776.png
# Guardando heatmap
# Generating heatmap
# Superponiendo heatmap
# Procesada: images_processed_heatmap\43004\2054900584.png
# Guardando heatmap
# Generating heatmap
# Superponiendo heatmap
# Procesada: images_processed_heatmap\51498\235064489.png
# Guardando heatmap
# Generating heatmap
# Superponiendo heatmap
# Procesada: images_processed_heatmap\31494\1176144373.png
# Guardando heatmap
# Generating heatmap
# Superponiendo heatmap
# Procesada: images_processed_heatmap\7974\1939799840.png
# Guardando heatmap
# Generating heatmap
# Superponiendo heatmap
# Procesada: images_processed_heatmap\30843\153894333.png
# Guardando heatmap
# Generating heatmap
# Superponiendo heatmap
# Procesada: images_processed_heatmap\4659\898286003.png
# Guardando heatmap
# Generating heatmap
# Superponiendo heatmap
# Procesada: images_processed_heatmap\39645\1378456920.png
# Guardando heatmap
# Generating heatmap
# Superponiendo heatmap
# Procesada: images_processed_heatmap\62285\921680758.png
# Guardando heatmap
# Generating heatmap
# Superponiendo heatmap
# Procesada: images_processed_heatmap\61981\1204439571.png
# Guardando heatmap
# Generating heatmap
# Superponiendo heatmap
# Procesada: images_processed_heatmap\53076\496152989.png
# Guardando heatmap
# Generating heatmap
# Superponiendo heatmap
# Procesada: images_processed_heatmap\6107\1280344998.png
# Guardando heatmap
# Generating heatmap
# Superponiendo heatmap
# Procesada: images_processed_heatmap\23893\58493989.png
# Guardando heatmap
# Generating heatmap
# Superponiendo heatmap
# Procesada: images_processed_heatmap\6866\1538678744.png
# Guardando heatmap
# Generating heatmap
# Superponiendo heatmap
# Procesada: images_processed_heatmap\58789\1426063277.png
# Guardando heatmap
# Generating heatmap
# Superponiendo heatmap
# Procesada: images_processed_heatmap\38219\29164169.png
# Guardando heatmap
# Generating heatmap
# Superponiendo heatmap
# Procesada: images_processed_heatmap\9965\1229053771.png
# Guardando heatmap
# Generating heatmap
# Superponiendo heatmap
# Procesada: images_processed_heatmap\11302\270983678.png
# Guardando heatmap
# Generating heatmap
# Superponiendo heatmap
# Procesada: images_processed_heatmap\6018\899067065.png
# Guardando heatmap
# Generating heatmap
# Superponiendo heatmap
# Procesada: images_processed_heatmap\14321\1094063340.png
# Guardando heatmap
# Generating heatmap
# Superponiendo heatmap
# Procesada: images_processed_heatmap\53386\946350395.png
# Guardando heatmap
# Generating heatmap
# Superponiendo heatmap
# Procesada: images_processed_heatmap\17657\555536867.png
# Guardando heatmap
# Generating heatmap
# Superponiendo heatmap
# Procesada: images_processed_heatmap\7012\10816335.png
# Guardando heatmap
# Generating heatmap
# Superponiendo heatmap
# Procesada: images_processed_heatmap\17402\1033350562.png
# Guardando heatmap
# Generating heatmap
# Superponiendo heatmap
# Procesada: images_processed_heatmap\10086\1479874325.png
# Guardando heatmap
# Generating heatmap
# Superponiendo heatmap
# Procesada: images_processed_heatmap\44070\748682794.png
# Guardando heatmap
# Generating heatmap
# Superponiendo heatmap
# Procesada: images_processed_heatmap\63768\762826582.png
# Guardando heatmap
# Generating heatmap
# Superponiendo heatmap
# Procesada: images_processed_heatmap\28748\1159321127.png
# Guardando heatmap
# Generating heatmap
# Superponiendo heatmap
# Procesada: images_processed_heatmap\17604\1371526669.png
# Guardando heatmap
# Generating heatmap
# Superponiendo heatmap
# Procesada: images_processed_heatmap\6941\2135064491.png
# Guardando heatmap
# Generating heatmap
# Superponiendo heatmap
# Procesada: images_processed_heatmap\63066\1145222737.png
# Guardando heatmap
# Generating heatmap
# Superponiendo heatmap
# Procesada: images_processed_heatmap\31698\620566032.png
# Guardando heatmap
# Generating heatmap
# Superponiendo heatmap
# Procesada: images_processed_heatmap\27447\263901674.png
# Guardando heatmap
# Generating heatmap
# Superponiendo heatmap
# Procesada: images_processed_heatmap\51426\1282873249.png
# Guardando heatmap
# Generating heatmap
# Superponiendo heatmap
# Procesada: images_processed_heatmap\28639\1494956649.png
# Guardando heatmap
# Generating heatmap
# Superponiendo heatmap
# Procesada: images_processed_heatmap\28209\617440973.png
# Guardando heatmap
# Generating heatmap
# Superponiendo heatmap
# Procesada: images_processed_heatmap\58797\882877053.png
# Guardando heatmap
# Generating heatmap
# Superponiendo heatmap
# Procesada: images_processed_heatmap\46774\854367487.png
# Guardando heatmap
# Generating heatmap
# Superponiendo heatmap
# Procesada: images_processed_heatmap\29203\497946051.png
# Guardando heatmap
# Generating heatmap
# Superponiendo heatmap
# Procesada: images_processed_heatmap\44914\1800010426.png
# Guardando heatmap
# Generating heatmap
# Superponiendo heatmap
# Procesada: images_processed_heatmap\51983\1582925028.png
# Guardando heatmap
# Generating heatmap
# Superponiendo heatmap
# Procesada: images_processed_heatmap\57941\1434826259.png
# Guardando heatmap
# Generating heatmap
# Superponiendo heatmap
# Procesada: images_processed_heatmap\44825\1004043684.png
# Guardando heatmap
# Generating heatmap
# Superponiendo heatmap
# Procesada: images_processed_heatmap\62552\306164126.png
# Guardando heatmap
# Generating heatmap
# Superponiendo heatmap
# Procesada: images_processed_heatmap\63522\1185337897.png
# Guardando heatmap
# Generating heatmap
# Superponiendo heatmap
# Procesada: images_processed_heatmap\13383\1636765957.png
# Guardando heatmap
# Generating heatmap
# Superponiendo heatmap
# Procesada: images_processed_heatmap\18380\1885254741.png
# Guardando heatmap
# Generating heatmap
# Superponiendo heatmap
# Procesada: images_processed_heatmap\51028\1007453929.png
# Guardando heatmap
# Generating heatmap
# Superponiendo heatmap
# Procesada: images_processed_heatmap\40941\762018265.png
# Guardando heatmap
# Generating heatmap
# Superponiendo heatmap
# Procesada: images_processed_heatmap\4019\1092089778.png
# Guardando heatmap
# Generating heatmap
# Superponiendo heatmap
# Procesada: images_processed_heatmap\51710\1315538800.png
# Guardando heatmap
# Generating heatmap
# Superponiendo heatmap
# Procesada: images_processed_heatmap\51664\1561392154.png
# Guardando heatmap
# Generating heatmap
# Superponiendo heatmap
# Procesada: images_processed_heatmap\53361\911388488.png
# Guardando heatmap
# Generating heatmap
# Superponiendo heatmap
# Procesada: images_processed_heatmap\28367\1708747078.png
# Guardando heatmap
# Generating heatmap
# Superponiendo heatmap
# Procesada: images_processed_heatmap\14981\1340320104.png
# Guardando heatmap
# Generating heatmap
# Superponiendo heatmap
# Procesada: images_processed_heatmap\33583\326653717.png
# Guardando heatmap
# Generating heatmap
# Superponiendo heatmap
# Procesada: images_processed_heatmap\40989\600843230.png
# Guardando heatmap
# Generating heatmap
# Superponiendo heatmap
# Procesada: images_processed_heatmap\15527\950188136.png
# Guardando heatmap
# Generating heatmap
# Superponiendo heatmap
# Procesada: images_processed_heatmap\10267\56268394.png
# Guardando heatmap
# Generating heatmap
# Superponiendo heatmap
# Procesada: images_processed_heatmap\30540\2097719388.png
# Guardando heatmap
# Generating heatmap
# Superponiendo heatmap
# Procesada: images_processed_heatmap\10973\485832157.png
# Guardando heatmap
# Generating heatmap
# Superponiendo heatmap
# Procesada: images_processed_heatmap\38241\2064129146.png
# Guardando heatmap
# Generating heatmap
# Superponiendo heatmap
# Procesada: images_processed_heatmap\46828\1754108593.png
# Guardando heatmap
# Generating heatmap
# Superponiendo heatmap
# Procesada: images_processed_heatmap\2810\1486023638.png
# Guardando heatmap
# Generating heatmap
# Superponiendo heatmap
# Procesada: images_processed_heatmap\1844\1565871400.png
# Guardando heatmap
# Generating heatmap
# Superponiendo heatmap
# Procesada: images_processed_heatmap\40888\19152831.png
# Guardando heatmap
# Generating heatmap
# Superponiendo heatmap
# Procesada: images_processed_heatmap\56110\1327802067.png
# Guardando heatmap
# Generating heatmap
# Superponiendo heatmap
# Procesada: images_processed_heatmap\14162\1487005959.png
# Guardando heatmap
# Generating heatmap
# Superponiendo heatmap
# Procesada: images_processed_heatmap\23590\661036489.png
# Guardando heatmap
# Generating heatmap
# Superponiendo heatmap
# Procesada: images_processed_heatmap\46668\1651498491.png
# Guardando heatmap
# Generating heatmap
# Superponiendo heatmap
# Procesada: images_processed_heatmap\33208\427988005.png
# Guardando heatmap
# Generating heatmap
# Superponiendo heatmap
# Procesada: images_processed_heatmap\49634\1352217793.png
# Guardando heatmap
# Generating heatmap
# Superponiendo heatmap
# Procesada: images_processed_heatmap\41177\306057258.png
# Guardando heatmap
# Generating heatmap
# Superponiendo heatmap
# Procesada: images_processed_heatmap\23398\1897862012.png
# Guardando heatmap
# Generating heatmap
# Superponiendo heatmap
# Procesada: images_processed_heatmap\14321\1196644994.png
# Guardando heatmap
# Generating heatmap
# Superponiendo heatmap
# Procesada: images_processed_heatmap\57754\186045163.png
# Guardando heatmap
# Generating heatmap
# Superponiendo heatmap
# Procesada: images_processed_heatmap\55514\2105616827.png
# Guardando heatmap
# Generating heatmap
# Superponiendo heatmap
# Procesada: images_processed_heatmap\57821\2107711606.png
# Guardando heatmap
# Generating heatmap
# Superponiendo heatmap
# Procesada: images_processed_heatmap\32740\208676208.png
# Guardando heatmap
# Generating heatmap
# Superponiendo heatmap
# Procesada: images_processed_heatmap\33534\2072094084.png
# Guardando heatmap
# Generating heatmap
# Superponiendo heatmap
# Procesada: images_processed_heatmap\1704\1786662475.png
# Guardando heatmap
# Generating heatmap
# Superponiendo heatmap
# Procesada: images_processed_heatmap\36286\1305247747.png
# Guardando heatmap
# Generating heatmap
# Superponiendo heatmap
# Procesada: images_processed_heatmap\48309\1131168002.png
# Guardando heatmap
# Generating heatmap
# Superponiendo heatmap
# Procesada: images_processed_heatmap\53659\1125098485.png
# Guardando heatmap
# Generating heatmap
# Superponiendo heatmap
# Procesada: images_processed_heatmap\40708\1453849012.png
# Guardando heatmap
# Generating heatmap
# Superponiendo heatmap
# Procesada: images_processed_heatmap\3463\950315175.png
# Guardando heatmap
# Generating heatmap
# Superponiendo heatmap
# Procesada: images_processed_heatmap\55881\1501216331.png
# Guardando heatmap
# Generating heatmap
# Superponiendo heatmap
# Procesada: images_processed_heatmap\12377\1702213333.png
# Guardando heatmap
# Generating heatmap
# Superponiendo heatmap
# Procesada: images_processed_heatmap\17535\492541558.png
# Guardando heatmap
# Generating heatmap
# Superponiendo heatmap
# Procesada: images_processed_heatmap\8631\155909056.png
# Guardando heatmap
# Generating heatmap
# Superponiendo heatmap
# Procesada: images_processed_heatmap\13001\892007000.png
# Guardando heatmap
# Generating heatmap
# Superponiendo heatmap
# Procesada: images_processed_heatmap\16692\219839681.png
# Guardando heatmap
# Generating heatmap
# Superponiendo heatmap
# Procesada: images_processed_heatmap\35618\1049190732.png
# Guardando heatmap
# Generating heatmap
# Superponiendo heatmap
# Procesada: images_processed_heatmap\25769\1584085040.png
# Guardando heatmap
# Generating heatmap
# Superponiendo heatmap
# Procesada: images_processed_heatmap\25909\512561149.png
# Guardando heatmap
# Generating heatmap
# Superponiendo heatmap
# Procesada: images_processed_heatmap\18786\997249696.png
# Guardando heatmap
# Generating heatmap
# Superponiendo heatmap
# Procesada: images_processed_heatmap\31988\315463824.png
# Guardando heatmap
# Generating heatmap
# Superponiendo heatmap
# Procesada: images_processed_heatmap\53115\892587620.png
# Guardando heatmap
# Generating heatmap
# Superponiendo heatmap
# Procesada: images_processed_heatmap\31280\1937468796.png
# Guardando heatmap
# Generating heatmap
# Superponiendo heatmap
# Procesada: images_processed_heatmap\42442\1793161801.png
# Guardando heatmap
# Generating heatmap
# Superponiendo heatmap
# Procesada: images_processed_heatmap\38945\723758013.png
# Guardando heatmap
# Generating heatmap
# Superponiendo heatmap
# Procesada: images_processed_heatmap\4824\2051028255.png
# Guardando heatmap
# Generating heatmap
# Superponiendo heatmap
# Procesada: images_processed_heatmap\37806\1783170877.png
# Guardando heatmap
# Generating heatmap
# Superponiendo heatmap
# Procesada: images_processed_heatmap\26145\1865066541.png
# Guardando heatmap
# Generating heatmap
# Superponiendo heatmap
# Procesada: images_processed_heatmap\16794\1465569015.png
# Guardando heatmap
# Generating heatmap
# Superponiendo heatmap
# Procesada: images_processed_heatmap\59756\112363376.png
# Guardando heatmap
# Generating heatmap
# Superponiendo heatmap
# Procesada: images_processed_heatmap\22860\1938449367.png
# Guardando heatmap
# Generating heatmap
# Superponiendo heatmap
# Procesada: images_processed_heatmap\42746\983919619.png
# Guardando heatmap
# Generating heatmap
# Superponiendo heatmap
# Procesada: images_processed_heatmap\29830\1208358068.png
# Guardando heatmap
# Generating heatmap
# Superponiendo heatmap
# Procesada: images_processed_heatmap\20254\12221717.png
# Guardando heatmap
# Generating heatmap
# Superponiendo heatmap
# Procesada: images_processed_heatmap\21445\468265579.png
# Guardando heatmap
# Generating heatmap
# Superponiendo heatmap
# Procesada: images_processed_heatmap\49135\1173702190.png
# Guardando heatmap
# Generating heatmap
# Superponiendo heatmap
# Procesada: images_processed_heatmap\64567\1602287486.png
# Guardando heatmap
# Generating heatmap
# Superponiendo heatmap
# Procesada: images_processed_heatmap\33107\1224552705.png
# Guardando heatmap
# Generating heatmap
# Superponiendo heatmap
# Procesada: images_processed_heatmap\42434\962027528.png
# Guardando heatmap
# Generating heatmap
# Superponiendo heatmap
# Procesada: images_processed_heatmap\25432\1283242087.png
# Guardando heatmap
# Generating heatmap
# Superponiendo heatmap
# Procesada: images_processed_heatmap\12305\1995339680.png
# Guardando heatmap
# Generating heatmap
# Superponiendo heatmap
# Procesada: images_processed_heatmap\28659\2101268408.png
# Guardando heatmap
# Generating heatmap
# Superponiendo heatmap
# Procesada: images_processed_heatmap\6928\750805544.png
# Guardando heatmap
# Generating heatmap
# Superponiendo heatmap
# Procesada: images_processed_heatmap\55538\10619420.png
# Guardando heatmap
# Generating heatmap
# Superponiendo heatmap
# Procesada: images_processed_heatmap\49520\767878280.png
# Guardando heatmap
# Generating heatmap
# Superponiendo heatmap
# Procesada: images_processed_heatmap\55002\1122354139.png
# Guardando heatmap
# Generating heatmap
# Superponiendo heatmap
# Procesada: images_processed_heatmap\64522\1477898213.png
# Guardando heatmap
# Generating heatmap
# Superponiendo heatmap
# Procesada: images_processed_heatmap\6659\834047789.png
# Guardando heatmap
# Generating heatmap
# Superponiendo heatmap
# Procesada: images_processed_heatmap\53946\535537301.png
# Guardando heatmap
# Generating heatmap
# Superponiendo heatmap
# Procesada: images_processed_heatmap\63884\1500781664.png
# Guardando heatmap
# Generating heatmap
# Superponiendo heatmap
# Procesada: images_processed_heatmap\45127\1622722991.png
# Guardando heatmap
# Generating heatmap
# Superponiendo heatmap
# Procesada: images_processed_heatmap\2882\1076134619.png
# Guardando heatmap
# Generating heatmap
# Superponiendo heatmap
# Procesada: images_processed_heatmap\5867\1153092111.png
# Guardando heatmap
# Generating heatmap
# Superponiendo heatmap
# Procesada: images_processed_heatmap\50855\368982920.png
# Guardando heatmap
# Generating heatmap
# Superponiendo heatmap
# Procesada: images_processed_heatmap\64385\371176944.png
# Guardando heatmap
# Generating heatmap
# Superponiendo heatmap
# Procesada: images_processed_heatmap\3820\513506400.png
# Guardando heatmap
# Generating heatmap
# Superponiendo heatmap
# Procesada: images_processed_heatmap\39320\913477151.png
# Guardando heatmap
# Generating heatmap
# Superponiendo heatmap
# Procesada: images_processed_heatmap\30553\961195055.png
# Guardando heatmap
# Generating heatmap
# Superponiendo heatmap
# Procesada: images_processed_heatmap\60885\1755101067.png
# Guardando heatmap
# Generating heatmap
# Superponiendo heatmap
# Procesada: images_processed_heatmap\46669\1758222964.png
# Guardando heatmap
# Generating heatmap
# Superponiendo heatmap
# Procesada: images_processed_heatmap\7022\801140479.png
# Guardando heatmap
# Generating heatmap
# Superponiendo heatmap
# Procesada: images_processed_heatmap\18626\975797108.png
# Guardando heatmap
# Generating heatmap
# Superponiendo heatmap
# Procesada: images_processed_heatmap\40345\1452790709.png
# Guardando heatmap
# Generating heatmap
# Superponiendo heatmap
# Procesada: images_processed_heatmap\27430\950994950.png
# Guardando heatmap
# Generating heatmap
# Superponiendo heatmap
# Procesada: images_processed_heatmap\39190\1169544511.png
# Guardando heatmap
# Generating heatmap
# Superponiendo heatmap
# Procesada: images_processed_heatmap\52627\2056624440.png
# Guardando heatmap
# Generating heatmap
# Superponiendo heatmap
# Procesada: images_processed_heatmap\29056\1766132603.png
# Guardando heatmap
# Generating heatmap
# Superponiendo heatmap
# Procesada: images_processed_heatmap\33932\1345263584.png
# Guardando heatmap
# Generating heatmap
# Superponiendo heatmap
# Procesada: images_processed_heatmap\11902\111743010.png
# Guardando heatmap
# Generating heatmap
# Superponiendo heatmap
# Procesada: images_processed_heatmap\5195\1872392300.png
# Guardando heatmap
# Generating heatmap
# Superponiendo heatmap
# Procesada: images_processed_heatmap\40819\36244284.png
# Guardando heatmap
# Generating heatmap
# Superponiendo heatmap
# Procesada: images_processed_heatmap\36061\1050111065.png
# Guardando heatmap
# Generating heatmap
# Superponiendo heatmap
# Procesada: images_processed_heatmap\16369\1583251467.png
# Guardando heatmap
# Generating heatmap
# Superponiendo heatmap
# Procesada: images_processed_heatmap\52642\1056336404.png
# Guardando heatmap
# Generating heatmap
# Superponiendo heatmap
# Procesada: images_processed_heatmap\34127\1249935400.png
# Guardando heatmap
# Generating heatmap
# Superponiendo heatmap
# Procesada: images_processed_heatmap\50234\578490027.png
# Guardando heatmap
# Generating heatmap
# Superponiendo heatmap
# Procesada: images_processed_heatmap\64209\1143137915.png
# Guardando heatmap
# Generating heatmap
# Superponiendo heatmap
# Procesada: images_processed_heatmap\33024\1976554916.png
# Guardando heatmap
# Generating heatmap
# Superponiendo heatmap
# Procesada: images_processed_heatmap\55969\2120282229.png
# Guardando heatmap
# Generating heatmap
# Superponiendo heatmap
# Procesada: images_processed_heatmap\7755\228050195.png
# Guardando heatmap
# Generating heatmap
# Superponiendo heatmap
# Procesada: images_processed_heatmap\47382\208877180.png
# Guardando heatmap
# Generating heatmap
# Superponiendo heatmap
# Procesada: images_processed_heatmap\46324\1629749211.png
# Guardando heatmap
# Generating heatmap
# Superponiendo heatmap
# Procesada: images_processed_heatmap\31864\1866737520.png
# Guardando heatmap
# Generating heatmap
# Superponiendo heatmap
# Procesada: images_processed_heatmap\53086\2092312524.png
# Guardando heatmap
# Generating heatmap
# Superponiendo heatmap
# Procesada: images_processed_heatmap\60519\1941196911.png
# Guardando heatmap
# Generating heatmap
# Superponiendo heatmap
# Procesada: images_processed_heatmap\52990\1471149497.png
# Guardando heatmap
# Generating heatmap
# Superponiendo heatmap
# Procesada: images_processed_heatmap\43601\1921240175.png
# Guardando heatmap
# Generating heatmap
# Superponiendo heatmap
# Procesada: images_processed_heatmap\60953\651642963.png
# Guardando heatmap
# Generating heatmap
# Superponiendo heatmap
# Procesada: images_processed_heatmap\14706\1060299310.png
# Guardando heatmap
# Generating heatmap
# Superponiendo heatmap
# Procesada: images_processed_heatmap\19888\1502730498.png
# Guardando heatmap
# Generating heatmap
# Superponiendo heatmap
# Procesada: images_processed_heatmap\29494\401065812.png
# Guardando heatmap
# Generating heatmap
# Superponiendo heatmap
# Procesada: images_processed_heatmap\10438\681193324.png
# Guardando heatmap
# Generating heatmap
# Superponiendo heatmap
# Procesada: images_processed_heatmap\18533\911473614.png
# Guardando heatmap
# Generating heatmap
# Superponiendo heatmap
# Procesada: images_processed_heatmap\31738\1220571008.png
# Guardando heatmap
# Generating heatmap
# Superponiendo heatmap
# Procesada: images_processed_heatmap\55969\2089051104.png
# Guardando heatmap
# Generating heatmap
# Superponiendo heatmap
# Procesada: images_processed_heatmap\11206\428958001.png
# Guardando heatmap
# Generating heatmap
# Superponiendo heatmap
# Procesada: images_processed_heatmap\1853\1981112667.png
# Guardando heatmap
# Generating heatmap
# Superponiendo heatmap
# Procesada: images_processed_heatmap\17535\952275239.png
# Guardando heatmap
# Generating heatmap
# Superponiendo heatmap
# Procesada: images_processed_heatmap\54743\816189185.png
# Guardando heatmap
# Generating heatmap
# Superponiendo heatmap
# Procesada: images_processed_heatmap\4377\1731824703.png
# Guardando heatmap
# Generating heatmap
# Superponiendo heatmap
# Procesada: images_processed_heatmap\49728\802739288.png
# Guardando heatmap
# Generating heatmap
# Superponiendo heatmap
# Procesada: images_processed_heatmap\10329\1074071142.png
# Guardando heatmap
# Generating heatmap
# Superponiendo heatmap
# Procesada: images_processed_heatmap\18263\595310253.png
# Guardando heatmap
# Generating heatmap
# Superponiendo heatmap
# Procesada: images_processed_heatmap\29338\2077252053.png
# Guardando heatmap
# Generating heatmap
# Superponiendo heatmap
# Procesada: images_processed_heatmap\41736\106416968.png
# Guardando heatmap
# Generating heatmap
# Superponiendo heatmap
# Procesada: images_processed_heatmap\65495\1435151627.png
# Guardando heatmap
# Generating heatmap
# Superponiendo heatmap
# Procesada: images_processed_heatmap\1963\2090715578.png
# Guardando heatmap
# Generating heatmap
# Superponiendo heatmap
# Procesada: images_processed_heatmap\53572\1472024330.png
# Guardando heatmap
# Generating heatmap
# Superponiendo heatmap
# Procesada: images_processed_heatmap\54112\1196068601.png
# Guardando heatmap
# Generating heatmap
# Superponiendo heatmap
# Procesada: images_processed_heatmap\23101\22058316.png
# Guardando heatmap
# Generating heatmap
# Superponiendo heatmap
# Procesada: images_processed_heatmap\30300\1408897139.png
# Guardando heatmap
# Generating heatmap
# Superponiendo heatmap
# Procesada: images_processed_heatmap\1878\189362032.png
# Guardando heatmap
# Generating heatmap
# Superponiendo heatmap
# Procesada: images_processed_heatmap\29986\1496079995.png
# Guardando heatmap
# Generating heatmap
# Superponiendo heatmap
# Procesada: images_processed_heatmap\37012\531540217.png
# Guardando heatmap
# Generating heatmap
# Superponiendo heatmap
# Procesada: images_processed_heatmap\44544\244683910.png
# Guardando heatmap
# Generating heatmap
# Superponiendo heatmap
# Procesada: images_processed_heatmap\57015\494034442.png
# Guardando heatmap
# Generating heatmap
# Superponiendo heatmap
# Procesada: images_processed_heatmap\64722\1121948452.png
# Guardando heatmap
# Generating heatmap
# Superponiendo heatmap
# Procesada: images_processed_heatmap\40747\1677788990.png
# Guardando heatmap
# Generating heatmap
# Superponiendo heatmap
# Procesada: images_processed_heatmap\18952\1238663835.png
# Guardando heatmap
# Generating heatmap
# Superponiendo heatmap
# Procesada: images_processed_heatmap\16197\150001369.png
# Guardando heatmap
# Generating heatmap
# Superponiendo heatmap
# Procesada: images_processed_heatmap\28747\285721109.png
# Guardando heatmap
# Generating heatmap
# Superponiendo heatmap
# Procesada: images_processed_heatmap\20337\272702480.png
# Guardando heatmap
# Generating heatmap
# Superponiendo heatmap
# Procesada: images_processed_heatmap\11817\723300969.png
# Guardando heatmap
# Generating heatmap
# Superponiendo heatmap
# Procesada: images_processed_heatmap\12091\193239486.png
# Guardando heatmap
# Generating heatmap
# Superponiendo heatmap
# Procesada: images_processed_heatmap\58628\1454611157.png
# Guardando heatmap
# Generating heatmap
# Superponiendo heatmap
# Procesada: images_processed_heatmap\3383\26698955.png
# Guardando heatmap
# Generating heatmap
# Superponiendo heatmap
# Procesada: images_processed_heatmap\3064\1931831839.png
# Guardando heatmap
# Generating heatmap
# Superponiendo heatmap
# Procesada: images_processed_heatmap\39658\1063239681.png
# Guardando heatmap
# Generating heatmap
# Superponiendo heatmap
# Procesada: images_processed_heatmap\61565\17179314.png
# Guardando heatmap
# Generating heatmap
# Superponiendo heatmap
# Procesada: images_processed_heatmap\9088\910123451.png
# Guardando heatmap
# Generating heatmap
# Superponiendo heatmap
# Procesada: images_processed_heatmap\10539\480140916.png
# Guardando heatmap
# Generating heatmap
# Superponiendo heatmap
# Procesada: images_processed_heatmap\27346\362348338.png
# Guardando heatmap
# Generating heatmap
# Superponiendo heatmap
# Procesada: images_processed_heatmap\3836\1149369074.png
# Guardando heatmap
# Generating heatmap
# Superponiendo heatmap
# Procesada: images_processed_heatmap\30435\137928966.png
# Guardando heatmap
# Generating heatmap
# Superponiendo heatmap
# Procesada: images_processed_heatmap\62955\745127769.png
# Guardando heatmap
# Generating heatmap
# Superponiendo heatmap
# Procesada: images_processed_heatmap\21161\1238906512.png
# Guardando heatmap
# Generating heatmap
# Superponiendo heatmap
# Procesada: images_processed_heatmap\4147\1605384630.png
# Guardando heatmap
# Generating heatmap
# Superponiendo heatmap
# Procesada: images_processed_heatmap\30824\2065242261.png
# Guardando heatmap
# Generating heatmap
# Superponiendo heatmap
# Procesada: images_processed_heatmap\26264\1789209859.png
# Guardando heatmap
# Generating heatmap
# Superponiendo heatmap
# Procesada: images_processed_heatmap\50414\1751403769.png
# Guardando heatmap
# Generating heatmap
# Superponiendo heatmap
# Procesada: images_processed_heatmap\12734\1390034646.png
# Guardando heatmap
# Generating heatmap
# Superponiendo heatmap
# Procesada: images_processed_heatmap\17641\664281938.png
# Guardando heatmap
# Generating heatmap
# Superponiendo heatmap
# Procesada: images_processed_heatmap\45193\1037714614.png
# Guardando heatmap
# Generating heatmap
# Superponiendo heatmap
# Procesada: images_processed_heatmap\44667\956592447.png
# Guardando heatmap
# Generating heatmap
# Superponiendo heatmap
# Procesada: images_processed_heatmap\25972\1202061797.png
# Guardando heatmap
# Generating heatmap
# Superponiendo heatmap
# Procesada: images_processed_heatmap\16136\14716440.png
# Guardando heatmap
# Generating heatmap
# Superponiendo heatmap
# Procesada: images_processed_heatmap\50688\1473124234.png
# Guardando heatmap
# Generating heatmap
# Superponiendo heatmap
# Procesada: images_processed_heatmap\48350\253719295.png
# Guardando heatmap
# Generating heatmap
# Superponiendo heatmap
# Procesada: images_processed_heatmap\55448\621694991.png
# Guardando heatmap
# Generating heatmap
# Superponiendo heatmap
# Procesada: images_processed_heatmap\37176\1896398439.png
# Guardando heatmap
# Generating heatmap
# Superponiendo heatmap
# Procesada: images_processed_heatmap\55836\50200363.png
# Guardando heatmap
# Generating heatmap
# Superponiendo heatmap
# Procesada: images_processed_heatmap\25523\690750133.png
# Guardando heatmap
# Generating heatmap
# Superponiendo heatmap
# Procesada: images_processed_heatmap\16256\633105964.png
# Guardando heatmap
# Generating heatmap
# Superponiendo heatmap
# Procesada: images_processed_heatmap\33624\788897862.png
# Guardando heatmap
# Generating heatmap
# Superponiendo heatmap
# Procesada: images_processed_heatmap\35723\1755228619.png
# Guardando heatmap
# Generating heatmap
# Superponiendo heatmap
# Procesada: images_processed_heatmap\23128\154651696.png
# Guardando heatmap
# Generating heatmap
# Superponiendo heatmap
# Procesada: images_processed_heatmap\22703\694656201.png
# Guardando heatmap
# Generating heatmap
# Superponiendo heatmap
# Procesada: images_processed_heatmap\57145\2025375255.png
# Guardando heatmap
# Generating heatmap
# Superponiendo heatmap
# Procesada: images_processed_heatmap\17183\1044781030.png
# Guardando heatmap
# Generating heatmap
# Superponiendo heatmap
# Procesada: images_processed_heatmap\16632\745406142.png
# Guardando heatmap
# Generating heatmap
# Superponiendo heatmap
# Procesada: images_processed_heatmap\32571\1923611919.png
# Guardando heatmap
# Generating heatmap
# Superponiendo heatmap
# Procesada: images_processed_heatmap\58974\723143862.png
# Guardando heatmap
# Generating heatmap
# Superponiendo heatmap
# Procesada: images_processed_heatmap\33687\1415296112.png
# Guardando heatmap
# Generating heatmap
# Superponiendo heatmap
# Procesada: images_processed_heatmap\64433\1456477033.png
# ...
# Superponiendo heatmap
# Procesada: images_processed_heatmap\28782\770796094.png
# Guardando heatmap
# Generating heatmap
# Superponiendo heatmap
# Procesada: images_processed_heatmap\45907\1445785088.png
# Guardando heatmap
# Generating heatmap
# Superponiendo heatmap
# Procesada: images_processed_heatmap\9387\568669745.png
# Guardando heatmap
# Generating heatmap
# Superponiendo heatmap
# Procesada: images_processed_heatmap\12830\929073459.png
# Guardando heatmap
# Generating heatmap
# Superponiendo heatmap
# Procesada: images_processed_heatmap\5590\671053837.png
# Guardando heatmap
# Generating heatmap
# Superponiendo heatmap
# Procesada: images_processed_heatmap\18316\148526504.png
# Guardando heatmap
# Generating heatmap
# Superponiendo heatmap
# Procesada: images_processed_heatmap\32319\1976056318.png
# Guardando heatmap
# Generating heatmap
# Superponiendo heatmap
# Procesada: images_processed_heatmap\52805\180456227.png
# Guardando heatmap
# Generating heatmap
# Superponiendo heatmap
# Procesada: images_processed_heatmap\43641\592358769.png
# Guardando heatmap
# Generating heatmap
# Superponiendo heatmap
# Procesada: images_processed_heatmap\58257\502525226.png
# Guardando heatmap
# Generating heatmap
# Superponiendo heatmap
# Procesada: images_processed_heatmap\65180\912049576.png
# Guardando heatmap
# Generating heatmap
# Superponiendo heatmap
# Procesada: images_processed_heatmap\28121\1147537695.png
# Guardando heatmap
# Generating heatmap
# Superponiendo heatmap
# Procesada: images_processed_heatmap\29028\1008138497.png
# Guardando heatmap
# Generating heatmap
# Superponiendo heatmap
# Procesada: images_processed_heatmap\13581\979587095.png
# Guardando heatmap
# Generating heatmap
# Superponiendo heatmap
# Procesada: images_processed_heatmap\23334\883504989.png
# Guardando heatmap
# Generating heatmap
# Superponiendo heatmap
# Procesada: images_processed_heatmap\23759\1993804315.png
# Guardando heatmap
# Generating heatmap
# Superponiendo heatmap
# Procesada: images_processed_heatmap\44894\505940911.png
# Guardando heatmap
# Generating heatmap
# Superponiendo heatmap
# Procesada: images_processed_heatmap\30317\2124226318.png
# Guardando heatmap
# Generating heatmap
# Superponiendo heatmap
# Procesada: images_processed_heatmap\50568\1230165797.png
# Guardando heatmap
# Generating heatmap
# Superponiendo heatmap
# Procesada: images_processed_heatmap\4017\288615875.png
# Guardando heatmap
# Generating heatmap
# Superponiendo heatmap
# Procesada: images_processed_heatmap\59635\322350327.png
# Guardando heatmap
# Generating heatmap
# Superponiendo heatmap
# Procesada: images_processed_heatmap\57874\363837585.png
# Guardando heatmap
# Generating heatmap
# Superponiendo heatmap
# Procesada: images_processed_heatmap\10973\143322096.png
# Guardando heatmap
# Generating heatmap
# Superponiendo heatmap
# Procesada: images_processed_heatmap\57877\1319410250.png
# Guardando heatmap
# Generating heatmap
# Superponiendo heatmap
# Procesada: images_processed_heatmap\43083\1943773948.png
# Guardando heatmap
# Generating heatmap
# Superponiendo heatmap
# Procesada: images_processed_heatmap\40552\1856007658.png
# Guardando heatmap
# Generating heatmap
# Superponiendo heatmap
# Procesada: images_processed_heatmap\32410\1391288828.png
# Guardando heatmap
# Generating heatmap
# Superponiendo heatmap
# Procesada: images_processed_heatmap\12725\1297379916.png
# Guardando heatmap
# Generating heatmap
# Superponiendo heatmap
# Procesada: images_processed_heatmap\48681\387555762.png
# Guardando heatmap
# Generating heatmap
# Superponiendo heatmap
# Procesada: images_processed_heatmap\48649\488628792.png
# Guardando heatmap
# Generating heatmap
# Superponiendo heatmap
# Procesada: images_processed_heatmap\21695\297282638.png
# Guardando heatmap
# Generating heatmap
# Superponiendo heatmap
# Procesada: images_processed_heatmap\1544\1262921739.png
# Guardando heatmap
# Generating heatmap
# Superponiendo heatmap
# Procesada: images_processed_heatmap\21224\1636016606.png
# Guardando heatmap
# Generating heatmap
# Superponiendo heatmap
# Procesada: images_processed_heatmap\33909\2130448144.png
# Guardando heatmap
# Generating heatmap
# Superponiendo heatmap
# Procesada: images_processed_heatmap\53183\1875865264.png
# Guardando heatmap
# Generating heatmap
# Superponiendo heatmap
# Procesada: images_processed_heatmap\13739\1612101821.png
# Guardando heatmap
# Generating heatmap
# Superponiendo heatmap
# Procesada: images_processed_heatmap\3411\1521425232.png
# Guardando heatmap
# Generating heatmap
# Superponiendo heatmap
# Procesada: images_processed_heatmap\34325\1690260996.png
# Guardando heatmap
# Generating heatmap
# Superponiendo heatmap
# Procesada: images_processed_heatmap\9215\236741593.png
# Guardando heatmap
# Generating heatmap
# Superponiendo heatmap
# Procesada: images_processed_heatmap\55148\926538150.png
# Guardando heatmap
# Generating heatmap
# Superponiendo heatmap
# Procesada: images_processed_heatmap\23543\1072305662.png
# Guardando heatmap
# Generating heatmap
# Superponiendo heatmap
# Procesada: images_processed_heatmap\49291\1198720917.png
# Guardando heatmap
# Generating heatmap
# Superponiendo heatmap
# Procesada: images_processed_heatmap\54795\320679560.png
# Guardando heatmap
# Generating heatmap
# Superponiendo heatmap
# Procesada: images_processed_heatmap\55724\451708491.png
# Guardando heatmap
# Generating heatmap
# Superponiendo heatmap
# Procesada: images_processed_heatmap\8785\402462048.png
# Guardando heatmap
# Generating heatmap
# Superponiendo heatmap
# Procesada: images_processed_heatmap\12988\1241879051.png
# Guardando heatmap
# Generating heatmap
# Superponiendo heatmap
# Procesada: images_processed_heatmap\62996\1386866094.png
# Guardando heatmap
# Generating heatmap
# Superponiendo heatmap
# Procesada: images_processed_heatmap\49950\1233155140.png
# Guardando heatmap
# Generating heatmap
# Superponiendo heatmap
# Procesada: images_processed_heatmap\29178\1032542264.png
# Guardando heatmap
# Generating heatmap
# Superponiendo heatmap
# Procesada: images_processed_heatmap\22836\1465766938.png
# Guardando heatmap
# Generating heatmap
# Superponiendo heatmap
# Procesada: images_processed_heatmap\51137\2122049229.png
# Guardando heatmap
# Generating heatmap
# Superponiendo heatmap
# Procesada: images_processed_heatmap\61292\693687948.png
# Guardando heatmap
# Generating heatmap
# Superponiendo heatmap
# Procesada: images_processed_heatmap\31890\237314584.png
# Guardando heatmap
# Generating heatmap
# Superponiendo heatmap
# Procesada: images_processed_heatmap\53220\711921001.png
# Guardando heatmap
# Generating heatmap
# Superponiendo heatmap
# Procesada: images_processed_heatmap\17894\75408744.png
# Guardando heatmap
# Generating heatmap
# Superponiendo heatmap
# Procesada: images_processed_heatmap\12149\2134134659.png
# Guardando heatmap
# Generating heatmap
# Superponiendo heatmap
# Procesada: images_processed_heatmap\18421\74185386.png
# Guardando heatmap
# Generating heatmap
# Superponiendo heatmap
# Procesada: images_processed_heatmap\63244\636746847.png
# Guardando heatmap
# Generating heatmap
# Superponiendo heatmap
# Procesada: images_processed_heatmap\16598\2088406419.png
# Guardando heatmap
# Generating heatmap
# Superponiendo heatmap
# Procesada: images_processed_heatmap\16580\38223454.png
# Guardando heatmap
# Generating heatmap
# Superponiendo heatmap
# Procesada: images_processed_heatmap\17487\80956868.png
# Guardando heatmap
# Generating heatmap
# Superponiendo heatmap
# Procesada: images_processed_heatmap\17133\1265652476.png
# Guardando heatmap
# Generating heatmap
# Superponiendo heatmap
# Procesada: images_processed_heatmap\63053\358240402.png
# Guardando heatmap
# Generating heatmap
# Superponiendo heatmap
# Procesada: images_processed_heatmap\4114\164539058.png
# Guardando heatmap
# Generating heatmap
# Superponiendo heatmap
# Procesada: images_processed_heatmap\62599\2039237856.png
# Guardando heatmap
# Generating heatmap
# Superponiendo heatmap
# Procesada: images_processed_heatmap\58540\356380138.png
# Guardando heatmap
# Generating heatmap
# Superponiendo heatmap
# Procesada: images_processed_heatmap\33594\1821648417.png
# Guardando heatmap
# Generating heatmap
# Superponiendo heatmap
# Procesada: images_processed_heatmap\65477\1548802831.png
# Guardando heatmap
# Generating heatmap
# Superponiendo heatmap
# Procesada: images_processed_heatmap\26078\1091782199.png
# Guardando heatmap
# Generating heatmap
# Superponiendo heatmap
# Procesada: images_processed_heatmap\22997\1092318422.png
# Guardando heatmap
# Generating heatmap
# Superponiendo heatmap
# Procesada: images_processed_heatmap\55630\1345955090.png
# Guardando heatmap
# Generating heatmap
# Superponiendo heatmap
# Procesada: images_processed_heatmap\49523\1187667771.png
# Guardando heatmap
# Generating heatmap
# Superponiendo heatmap
# Procesada: images_processed_heatmap\22130\144755236.png
# Guardando heatmap
# Generating heatmap
# Superponiendo heatmap
# Procesada: images_processed_heatmap\53661\808826790.png
# Guardando heatmap
# Generating heatmap
# Superponiendo heatmap
# Procesada: images_processed_heatmap\10838\591123709.png
# Guardando heatmap
# Generating heatmap
# Superponiendo heatmap
# Procesada: images_processed_heatmap\50436\1345252118.png
# Guardando heatmap
# Generating heatmap
# Superponiendo heatmap
# Procesada: images_processed_heatmap\12787\250518053.png
# Guardando heatmap
# Generating heatmap
# Superponiendo heatmap
# Procesada: images_processed_heatmap\4822\60861218.png
# Guardando heatmap
# Generating heatmap
# Superponiendo heatmap
# Procesada: images_processed_heatmap\13868\1631171838.png
# Guardando heatmap
# Generating heatmap
# Superponiendo heatmap
# Procesada: images_processed_heatmap\22877\1784537872.png
# Guardando heatmap
# Generating heatmap
# Superponiendo heatmap
# Procesada: images_processed_heatmap\39681\1126805226.png
# Guardando heatmap
# Generating heatmap
# Superponiendo heatmap
# Procesada: images_processed_heatmap\43618\185297625.png
# Guardando heatmap
# Generating heatmap
# Superponiendo heatmap
# Procesada: images_processed_heatmap\15846\314932821.png
# Guardando heatmap
# Generating heatmap
# Superponiendo heatmap
# Procesada: images_processed_heatmap\34992\626393622.png
# Guardando heatmap
# Generating heatmap
# Superponiendo heatmap
# Procesada: images_processed_heatmap\54932\78867874.png
# Guardando heatmap
# Generating heatmap
# Superponiendo heatmap
# Procesada: images_processed_heatmap\2841\1204520054.png
# Guardando heatmap
# Generating heatmap
# Superponiendo heatmap
# Procesada: images_processed_heatmap\45113\744971924.png
# Guardando heatmap
# Generating heatmap
# Superponiendo heatmap
# Procesada: images_processed_heatmap\39460\1751135866.png
# Guardando heatmap
# Generating heatmap
# Superponiendo heatmap
# Procesada: images_processed_heatmap\49343\591280526.png
# Guardando heatmap
# Generating heatmap
# Superponiendo heatmap
# Procesada: images_processed_heatmap\4495\1158650504.png
# Guardando heatmap
# Generating heatmap
# Superponiendo heatmap
# Procesada: images_processed_heatmap\64088\1421066479.png
# Guardando heatmap
# Generating heatmap
# Superponiendo heatmap
# Procesada: images_processed_heatmap\32198\458629158.png
# Guardando heatmap
# Generating heatmap
# Superponiendo heatmap
# Procesada: images_processed_heatmap\55611\1564215425.png
# Guardando heatmap
# Generating heatmap
# Superponiendo heatmap
# Procesada: images_processed_heatmap\34554\27539646.png
# Guardando heatmap
# Generating heatmap
# Superponiendo heatmap
# Procesada: images_processed_heatmap\14552\942953173.png
# Guardando heatmap
# Generating heatmap
# Superponiendo heatmap
# Procesada: images_processed_heatmap\59021\443453185.png
# Guardando heatmap
# Generating heatmap
# Superponiendo heatmap
# Procesada: images_processed_heatmap\32984\1263963937.png
# Guardando heatmap
# Generating heatmap
# Superponiendo heatmap
# Procesada: images_processed_heatmap\24752\1546041515.png
# Guardando heatmap
# Generating heatmap
# Superponiendo heatmap
# Procesada: images_processed_heatmap\58168\1277856808.png
# Guardando heatmap
# Generating heatmap
# Superponiendo heatmap
# Procesada: images_processed_heatmap\6687\704347321.png
# Guardando heatmap
# Generating heatmap
# Superponiendo heatmap
# Procesada: images_processed_heatmap\15842\1909808599.png
# Guardando heatmap
# Generating heatmap
# Superponiendo heatmap
# Procesada: images_processed_heatmap\19159\471172267.png
# Guardando heatmap
# Generating heatmap
# Superponiendo heatmap
# Procesada: images_processed_heatmap\58594\405604140.png
# Guardando heatmap
# Generating heatmap
# Superponiendo heatmap
# Procesada: images_processed_heatmap\9583\1142459425.png
# Guardando heatmap
# Generating heatmap
# Superponiendo heatmap
# Procesada: images_processed_heatmap\59782\46120512.png
# Guardando heatmap
# Generating heatmap
# Superponiendo heatmap
# Procesada: images_processed_heatmap\7940\995464653.png
# Guardando heatmap
# Generating heatmap
# Superponiendo heatmap
# Procesada: images_processed_heatmap\9008\947101947.png
# Guardando heatmap
# Generating heatmap
# Superponiendo heatmap
# Procesada: images_processed_heatmap\42969\1775890856.png
# Guardando heatmap
# Generating heatmap
# Superponiendo heatmap
# Procesada: images_processed_heatmap\47653\728072902.png
# Guardando heatmap
# Generating heatmap
# Superponiendo heatmap
# Procesada: images_processed_heatmap\8041\1504952780.png
# Guardando heatmap
# Generating heatmap
# Superponiendo heatmap
# Procesada: images_processed_heatmap\38037\688756793.png
# Guardando heatmap
# Generating heatmap
# Superponiendo heatmap
# Procesada: images_processed_heatmap\28605\1230437394.png
# Guardando heatmap
# Generating heatmap
# Superponiendo heatmap
# Procesada: images_processed_heatmap\63836\1109952609.png
# Guardando heatmap
# Generating heatmap
# Superponiendo heatmap
# Procesada: images_processed_heatmap\967\1656607222.png
# Guardando heatmap
# Generating heatmap
# Superponiendo heatmap
# Procesada: images_processed_heatmap\39066\2051386501.png
# Guardando heatmap
# Generating heatmap
# Superponiendo heatmap
# Procesada: images_processed_heatmap\4216\1609690078.png
# Guardando heatmap
# Generating heatmap
# Superponiendo heatmap
# Procesada: images_processed_heatmap\59724\68772829.png
# Guardando heatmap
# Generating heatmap
# Superponiendo heatmap
# Procesada: images_processed_heatmap\37454\1064648689.png
# Guardando heatmap
# Generating heatmap
# Superponiendo heatmap
# Procesada: images_processed_heatmap\44745\889528386.png
# Guardando heatmap
# Generating heatmap
# Superponiendo heatmap
# Procesada: images_processed_heatmap\41639\1969057741.png
# Guardando heatmap
# Generating heatmap
# Superponiendo heatmap
# Procesada: images_processed_heatmap\41284\307628639.png
# Guardando heatmap
# Generating heatmap
# Superponiendo heatmap
# Procesada: images_processed_heatmap\27834\1333389840.png
# Guardando heatmap
# Generating heatmap
# Superponiendo heatmap
# Procesada: images_processed_heatmap\49461\2132016159.png
# Guardando heatmap
# Generating heatmap
# Superponiendo heatmap
# Procesada: images_processed_heatmap\55300\2109085790.png
# Guardando heatmap
# Generating heatmap
# Superponiendo heatmap
# Procesada: images_processed_heatmap\17373\1658853259.png
# Guardando heatmap
# Generating heatmap
# Superponiendo heatmap
# Procesada: images_processed_heatmap\60716\1996114707.png
# Guardando heatmap
# Generating heatmap
# Superponiendo heatmap
# Procesada: images_processed_heatmap\28605\1640139569.png
# Guardando heatmap
# Generating heatmap
# Superponiendo heatmap
# Procesada: images_processed_heatmap\56166\28500633.png
# Guardando heatmap
# Generating heatmap
# Superponiendo heatmap
# Procesada: images_processed_heatmap\36570\1870071397.png
# Guardando heatmap
# Generating heatmap
# Superponiendo heatmap
# Procesada: images_processed_heatmap\14298\2130546785.png
# Guardando heatmap
# Generating heatmap
# Superponiendo heatmap
# Procesada: images_processed_heatmap\3346\1063196710.png
# Guardando heatmap
# Generating heatmap
# Superponiendo heatmap
# Procesada: images_processed_heatmap\6794\1601652434.png
# Guardando heatmap
# Generating heatmap
# Superponiendo heatmap
# Procesada: images_processed_heatmap\23764\937956997.png
# Guardando heatmap
# Generating heatmap
# Superponiendo heatmap
# Procesada: images_processed_heatmap\8742\819926265.png
# Guardando heatmap
# Generating heatmap
# Superponiendo heatmap
# Procesada: images_processed_heatmap\22970\117988714.png
# Guardando heatmap
# Generating heatmap
# Superponiendo heatmap
# Procesada: images_processed_heatmap\29198\1440650112.png
# Guardando heatmap
# Generating heatmap
# Superponiendo heatmap
# Procesada: images_processed_heatmap\46043\1260717245.png
# Guardando heatmap
# Generating heatmap
# Superponiendo heatmap
# Procesada: images_processed_heatmap\54085\234391345.png
# Guardando heatmap
# Generating heatmap
# Superponiendo heatmap
# Procesada: images_processed_heatmap\63785\1071946733.png

# %%
base_path='images_processed_heatmap'

# saving image path into train dataframe
balanced_df['img_path']= balanced_df.patient_id.astype(str)\
                    + '/' + balanced_df.image_id.astype(str)\
                    + '.png'



display(balanced_df.head(3))
# Out:
#    site_id  patient_id    image_id laterality view   age  cancer  biopsy  \
# 0        1       65030  1344606626          L  MLO  56.0       0       0
# 1        2       31859    78460969          R   CC  68.0       0       0
# 2        1        7098   786606520          R   CC  59.0       0       0
#
#    invasive  BIRADS  implant density  machine_id  difficult_negative_case  \
# 0         0     1.0        0       B          49                    False
# 1         0     1.0        0     NaN          48                    False
# 2         0     1.0        0       B         210                    False
#
#                img_path  label
# 0  65030/1344606626.png      0
# 1    31859/78460969.png      0
# 2    7098/786606520.png      0
